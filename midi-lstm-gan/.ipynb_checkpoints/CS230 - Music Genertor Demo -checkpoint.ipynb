# %%
import mlp_gan
# Out:
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from IPython.display import Image
Image("discriminator_plot.png")

# %%
gan = mlp_gan.GAN(rows=100)
gan.get_generator.load_weights('cgan_generator.h5')
notes = gan.generate(1, 2)
# Out:
# Column names are Nro, Register, Mode, Tempo, Soundlevel, Articulation, Timbre, Melody
# Parsing ../data/midi/024.mid
# Parsing ../data/midi/103.mid
# Parsing ../data/midi/146.mid
# Parsing ../data/midi/067.mid
# Parsing ../data/midi/127.mid
# Parsing ../data/midi/119.mid
# Parsing ../data/midi/051.mid
# Parsing ../data/midi/032.mid
# Parsing ../data/midi/198.mid
# Parsing ../data/midi/016.mid
# Parsing ../data/midi/172.mid
# Parsing ../data/midi/175.mid
# Parsing ../data/midi/181.mid
# Parsing ../data/midi/105.mid
# Parsing ../data/midi/074.mid
# Parsing ../data/midi/118.mid
# Parsing ../data/midi/174.mid
# Parsing ../data/midi/166.mid
# Parsing ../data/midi/073.mid
# Parsing ../data/midi/060.mid
# Parsing ../data/midi/122.mid
# Parsing ../data/midi/185.mid
# Parsing ../data/midi/046.mid
# Parsing ../data/midi/098.mid
# Parsing ../data/midi/037.mid
# Parsing ../data/midi/033.mid
# Parsing ../data/midi/167.mid
# Parsing ../data/midi/149.mid
# Parsing ../data/midi/110.mid
# ...

# %%
print(notes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-488fdd4b92c2> in <module>
# ----> 1 print(notes)
#
# NameError: name 'notes' is not defined
